# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import pandas as pd
from explore.funcs import load_datasets, get_docs

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
model = SentenceTransformer("BAAI/bge-m3")

# %%
datasets = load_datasets(["ru", "zh", "fa"])

datasets
# Out:
# {'ru': Dataset(id='neuclir/1/ru/hc4-filtered', provides=['docs', 'queries', 'qrels']),
#  'zh': Dataset(id='neuclir/1/zh/hc4-filtered', provides=['docs', 'queries', 'qrels']),
#  'fa': Dataset(id='neuclir/1/fa/hc4-filtered', provides=['docs', 'queries', 'qrels'])}

# %%
documents = pd.DataFrame(datasets["ru"].docs_iter())

documents.count()
# Out:
# doc_id     964719
# title      964719
# text       964719
# url        964719
# time       215421
# cc_file    964719
# dtype: int64

# %%
queries = pd.DataFrame(datasets["ru"].queries_iter())

queries
# Out:
#    query_id                                              title  \
# 0         3                         British royal news impacts
# 1         6               Gibraltar's Sovereignty After Brexit
# 2        13                     US-South Korea Trade Agreement
# 3        14       North Korean Earthquakes and Nuclear Testing
# 4       101           Shipwrecks and Historical European Trade
# 5       103          African Extremist School Girls Kidnapping
# 6       105                           Mount Sinabung Eruptions
# 7       107                UN Climate Change Economic Analysis
# 8       108            Saudi Arabic movie theater restrictions
# 9       111                     Chinese regulation of Fentanyl
# 10      113                        Boeing 737 Flight 610 Crash
# 11      114         Causes of Forest Fires in central Portugal
# 12      116          Russian reaction to Maduro-Guaidó dispute
# 13      126                  Notre Dame restoration technology
# 14      127                      Brumadinho dam collapse cause
# 15      128                        White Rhinoceros Extinction
# 16      133           Foreign student espionage charges in UAE
# 17      134       Iran Transports Explosives to France in 2018
# 18      135                          Viability of UK Spaceport
# 19      136  Greenland's climate change-induced geologic ac...
# 20      137  Chiapas and Puebla earthquakes causal relation...
# 21      138              Vaquita porpoise conservation efforts
# 22      142                   U.S. troop levels in Afghanistan
# 23      146     Prehistoric human discoveries in South America
# 24      150                   2018 Papua New Guinea Earthquake
# 25      151          Chinese Government Response to Landslides
# 26      157               Slowing the anthropogenic extinction
# 27      158  Turkey's response to Kurdish independence refe...
# 28      161           Event Horizon Telescope blackhole images
# 29      164                  OPCW report Douma chemical attack
# 30      172                   Sex and Gender Rights in Germany
# 31      179        Iranian international transactions in euros
# 32      185           Kuwait's role in Qatar diplomatic crisis
# 33      192               Criteria for Hosting Summer Olympics
# 34      199         Impeachment of South Korean President Park
# 35      208                        Bird reintroduction to wild
# 36      229        Media industry mergers effects stock prices
# 37      230                    Tongan Damage from Cyclone Gita
# 38      231            Economic impact of Saudi women's rights
# 39      232    Pilots strike causes Ryanair flight cancelation
# 40      233                 Weinstein sexual misconduct impact
# 41      234    Preventing illicitly tapped pipelines in Mexico
# 42      245  China-Germany partnership battling climate change
# 43      246  Sri Lankan Court overturns suspension of Parli...
# 44      247                           China railway investment
# 45      248               States Response to Trump ending DACA
# 46      249                          #metoo Movement in Russia
# 47      250                           Sibrian Wildfires Causes
# 48      251                     Recovery from Kilauea eruption
# 49      252                 Haitian armed forces reinstatement
# 50      253                   Bus Accidents in the Philippines
# 51      254              Russian Social media companies growth
# 52      255              Chinese President Term Limits removed
# 53      256         Causes of Mediterranean migrants drownings
#
#                                           description  \
# 0   What political and economic impacts does news ...
# 1   How will Gibraltar's sovereignty be impacted b...
# 2   How will South Korea benefit from or be harmed...
# 3   Are earthquakes in North Korea being caused by...
# 4   What information about trade and shipping has ...
# 5   What is known about instances of extremist or ...
# 6   How long will Mount Sinabung's eruptions last ...
# 7   What is the economic impact of climate change ...
# 8   What restrictions did Saudi Arabia put on movi...
# 9   Has the addition of fentanyl to China's list o...
# 10  What caused the Lion Air Flight 610 Boeing 737...
# 11  What are the causes of the forest fires in cen...
# 12  What is the position of Russia concerning the ...
# 13  What roles are technology playing in the resto...
# 14  What caused the collapse of the dam at the Cór...
# 15  Which white rhinoceros subspecies are extinct ...
# 16  What information is available about foreign st...
# 17  Is there evidence that Iranian-sponsored group...
# 18  What plans are being developed to ensure the c...
# 19  Has climate change contributed to an increase ...
# 20  Is there evidence of a causal relationship bet...
# 21  What actions are being taken by governments an...
# 22  What changes has the United States announced r...
# 23  What have recent discoveries of prehistoric re...
# 24  How many people were injured or killed by eart...
# 25  How is the Chinese government responding to th...
# 26  What approaches have been proposed to slow the...
# 27  How did Turkey react to the 2017 Kurdish refer...
# 28  What do the images of blackholes obtained by t...
# 29  What conclusions did the Organisation for the ...
# 30  To what extent are sexual and gender identity ...
# 31  How will Iran's decision to base its internati...
# 32  What role did Kuwait have in mediating the 201...
# 33  What conditions do cities need to meet in orde...
# 34  What events led to the impeachment of South Ko...
# 35  Which species of birds of prey have been succe...
# 36  How are media industry mergers effecting stock...
# 37  Aside from damage to buildings, what other inf...
# 38  What economic changes are happening in Saudi A...
# 39  Which Ryanair flights were canceled as a resul...
# 40  How will being sued for sexual harassment and ...
# 41  What steps does the Mexican government propose...
# 42  How have China and Germany agreed to expand th...
# 43  Did the Sri Lankan Supreme Court's decision in...
# 44  What investments are being made for railway pr...
# 45  How did the State governments react to Preside...
# 46  What actions have been identified with the #me...
# 47  What is the primary cause of the wildfires in ...
# 48  What is the cost of economic recovery from Haw...
# 49          Why did Haiti reinstate its armed forces?
# 50  What are the causes, severity, and trends of b...
# 51  What are the reasons for record user engagemen...
# 52  What is the intent of Xi Jinping removing term...
# 53  What are the causes of migrants drowning while...
#
#                                              ht_title  \
# 0             Влияние британских королевских новостей
# 1               Суверенитет Гибралтара после Брексита
# 2               США-Южнокорейское торговое соглашение
# 3   Северокорейские землетрясения и ядерное испытание
# 4   Кораблекрушения и историческая Европейская тор...
# 5   Похищение школьниц из числа африканских экстре...
# 6                            Извержения горы Синабунг
# 7          ООН Изменение Климата Экономический Анализ
# 8          Ограничения кинотеатра в Саудовской Аравии
# 9                   Китайское регулирование Фентанила
# 10                      Крушение Боинга 737 рейса 610
# 11  Причины лесных попожаров в центральной Португалии
# 12               Реакция России на спор Мадуро-Гуайдо
# 13                   технология реставрации Нотр-Дама
# 14               Причина обрушения плотины Брумадиньо
# 15                          Вымирание белых носорогов
# 16   Обвинения в шпионаже иностранных студентов в ОАЭ
# 29  К каким выводам пришла Организация по Запрещен...
# 30  Насколько защищены права на сексуальную и генд...
# 31  Как повлияет на американо-иранские отношения р...
# 32  Какую роль сыграл Кувейт в посредничестве дипл...
# 33  Каким условиям должны соответствовать города, ...
# 34  Какие события привели к импичменту президента ...
# 35  Какие виды хищных птиц были успешно возвращены...
# 36   Как слияния медиаиндустрии влияют на цены акций?
# 37  Помимо повреждений зданий, какие другие инфрас...
# 38  Какие экономические изменения происходят в Сау...
# 39  Какие рейсы Ryanair были отменены в результате...
# 40  Как судебный иск за сексуальные домогательства...
# 41  Какие шаги предлагает предпринять мексиканское...
# 42  Как Китай и Германия согласились расширить сво...
# 43  Решило ли решение Верховного суда Шри-Ланки от...
# 44  Какие инвестиции вкладываются в Китайские желе...
# 45  Как правительства штатов отреагировали на реше...
# 46  Какие действия были связаны с движением #MeToo...
# 47  Что является основной причиной лесных пожаров ...
# 48  Какова стоимость восстановления экономики посл...
# 49   Почему Гаити восстановило свои вооруженные силы?
# 50  Какие причины, серьезность и тенденции автобус...
# 51  Какие причины рекордного взаимодействия пользо...
# 52  Каковы намерения Си Цзиньпина, отменяющего огр...
# 53  По каким причинам мигранты тонут при попытке п...
#
#                                              mt_title  \
# 0               Британские королевские новости влияют
# 1               Суверенитет Гибралтара после Брексита
# 2        Торговое соглашение между США и Южной Кореей
# 3   Северокорейские землетрясения и ядерные испытания
# 4   Кораблекрушения и историческая европейская тор...
# 5   Африканские Экстремистские Школьные Девушки По...
# 6                         Разрушения на горе Синабунг
# 7          Экономический анализ изменения климата ООН
# 8        Ограничения саудовского арабского кинотеатра
# 9                   Китайское регулирование Фентанила
# 10                         Boeing 737 Рейс 610 Авария
# 11    Причины лесных пожаров в центральной Португалии
# 12               Реакция России на спор Мадуро-Гуайдо
# 13                 Технология восстановления Нотр-Дам
# 14               Причина обрушения плотины Брумадиньо
# 15                           Белый носорог Extinction
# 16       Штраф за шпионаж иностранных студентов в ОАЭ
# 17  Иран транспортирует взрывчатые вещества во Фра...
# 18              Жизненность космодрома Великобритании
# 19  Геологическая активность Гренландии, вызванная...
# 20  Причинно-следственная связь землетрясений Чьяп...
# 21                Усилия по сохранению порций Vaquita
# 22                Численность войск США в Афганистане
# 23  Доисторические человеческие открытия в Южной А...
# 24   Землетрясение в Папуа — Новой Гвинее в 2018 году
# 25               Ответ правительства Китая на оползни
# 26                Замедление антропогенного вымирания
# 27  Ответ Турции на референдум по вопросу о незави...
# 28      Event Horizon телескоп черных дыр изображения
# 29       ОЗХО сообщила о химическом нападении на Думу
# 30           Сексуальные и гендерные права в Германии
# 31               Иранские международные сделки в евро
# 32    Роль Кувейта в дипломатическом кризисе в Катаре
# 33         Критерии проведения летних Олимпийских игр
# 34          Импичмент Южнокорейского президента Парка
# 35                 Реинтродукция птиц в дикую природу
# 36       Слияния медиа-индустрии влияют на цены акций
# 37                    Тонганский урон от циклона Гита
# 38   Экономическое воздействие прав саудовских женщин
# 39         Удар пилотов вызывает отмену рейса Ryanair
# 40          Влияние сексуального проступка Вайнштейна
# 41  Предотвращение незаконного прохода трубопровод...
# 42  Китайско-германское партнерство в борьбе с изм...
# 43  Суд Шри-Ланки отменил приостановление работы п...
# 44                 Инвестиции в железные дороги Китая
# 45   Ответ государств на Трампа, заканчивающийся DACA
# 46                          # metoo Движение в России
# 47                   Сибрийские лесные пожары Причины
# 48            Восстановление после извержения Килауэи
# 49               Восстановление вооруженных сил Гаити
# 50                    Автобусные аварии на Филиппинах
# 51        Рост российских компаний в социальных сетях
# 52              Президент Китая Термин Лимиты удалены
# 53      Причины утопления средиземноморских мигрантов
#
#                                        mt_description  \
# 0   Какие политические и экономические последствия...
# 1   Как повлияют на суверенитет Гибралтара перегов...
# 2   Каким образом Южная Корея извлечет выгоду из с...
# 3   Являются ли землетрясения в Северной Корее при...
# 4   Какая информация о торговле и судоходстве была...
# 5   Что известно о случаях похищения девочками из ...
# 6   Как долго будут продолжаться извержения горы С...
# 7   Каково экономическое воздействие изменения кли...
# 8   Какие ограничения были введены Саудовской Арав...
# 9   Успешно ли было включение фентанила в перечень...
# 10  Что привело к падению самолета Boeing 737 авиа...
# 11  Каковы причины лесных пожаров в центральной ча...
# 12  Какова позиция России по поводу президентского...
# 13  Какую роль играет технология в восстановлении ...
# 14  Что вызвало обрушение плотины на руднике желез...
# 15  Какие подвиды белых носорогов вымерли или почт...
# 16  Какую информацию можно получить о том, что ино...
# 17  Есть ли доказательства того, что спонсируемые ...
# 18  Какие планы разрабатываются для обеспечения ко...
# 19  Способствует ли изменение климата увеличению ч...
# 20  Есть ли доказательства причинно-следственной с...
# 21  Какие меры принимаются правительствами и частн...
# 22  Какие изменения объявили Соединенные Штаты в о...
# 23  Что показали недавние открытия доисторических ...
# 24  Сколько людей было ранено или убито в результа...
# 25  Как китайское правительство реагирует на часты...
# 26  Какие подходы были предложены для замедления а...
# 27  Как Турция отреагировала на курдский референду...
# 28  Что показывают изображения черных дыр, получен...
# 29  Какие выводы сделала Организация по запрещению...
# 30  В какой степени обеспечивается защита прав на ...
# 31  Как решение Ирана основывать свои международны...
# 32  Какую роль сыграл Кувейт в посредничестве в ди...
# 33  Какие условия необходимо соблюдать городам для...
# 34  Какие события привели к импичменту президента ...
# 35  Какие виды хищных птиц были успешно возвращены...
# 36  Как слияния медиа-индустрии влияют на цены акций?
# 37  Помимо ущерба зданиям, какая другая инфраструк...
# 38  Какие экономические изменения происходят в Сау...
# 39  Какие рейсы Ryanair были отменены в результате...
# 40  Как судебное преследование за сексуальные домо...
# 41  Какие шаги планирует предпринять мексиканское ...
# 42  Как Китай и Германия согласились расширить сво...
# 43  Решает ли решение Верховного суда Шри-Ланки в ...
# 44  Какие инвестиции вкладываются в железнодорожны...
# 45  Как правительства штатов отреагировали на реше...
# 46  Какие действия были идентифицированы с движени...
# 47   Какова основная причина лесных пожаров в Сибири?
# 48  Какова стоимость экономического восстановления...
# 49   Почему Гаити восстановила свои вооруженные силы?
# 50  Каковы причины, серьезность и тенденции дорожн...
# 51  Каковы причины для регистрации взаимодействия ...
# 52  Каково намерение Си Цзиньпина снять ограничени...
# 53  Каковы причины утопления мигрантов при попытке...
#
#                                narrative_by_relevance  \
# 0   {'very_valuable': 'Information regarding econo...
# 1   {'very_valuable': 'Gibraltar will remain a ter...
# 2   {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 3   {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 4   {'very_valuable': 'Shipwrecks that belonged to...
# 5   {'very_valuable': 'The number and instances of...
# 6   {'very_valuable': 'None found', 'somewhat_valu...
# 7   {'very_valuable': 'Articles that described the...
# 8   {'very_valuable': 'Described the restrictions ...
# 9   {'very_valuable': 'One article focused on the ...
# 10  {'very_valuable': 'One article that had all th...
# 11  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 12  {'very_valuable': 'Two articles detailed actio...
# 13  {'very_valuable': 'A couple articles detailed ...
# 14  {'very_valuable': 'states reason and provides ...
# 15  {'very_valuable': 'Northern white rhino males ...
# 16  {'very_valuable': 'References foreign students...
# 17  {'very_valuable': 'Information about explosive...
# 18  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 19  {'very_valuable': 'Relates Greenland Geologic ...
# 20  {'very_valuable': 'Relationship between the ea...
# 21  {'very_valuable': 'Use of Navy trained dolphin...
# 22  {'very_valuable': 'Announcement regarding troo...
# 23  {'very_valuable': 'References human remains fr...
# 24  {'very_valuable': 'specific number of dead or ...
# 25  {'very_valuable': 'Representative of People's ...
# 26  {'very_valuable': 'Two articles had very detai...
# 27  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 28  {'very_valuable': 'One article went into detai...
# 29  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 30  {'very_valuable': 'Column "other" was introduc...
# 31  {'very_valuable': 'Mentions sanctions in conne...
# 32  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 33  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 34  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 35  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 36  {'very_valuable': 'NA', 'somewhat_valuable': '...
# 37  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 38  {'very_valuable': 'New initiatives in Saudi Ar...
# 39  {'very_valuable': 'Ryanair cancelled up to 600...
# 40  {'very_valuable': 'Described scandal associate...
# 41  {'very_valuable': 'Except for the first one I ...
# 42  {'very_valuable': 'Germany and China send a si...
# 43  {'very_valuable': 'Sri Lanka was left without ...
# 44  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 45  {'very_valuable': 'US court ordered the govern...
# 46  {'very_valuable': 'One detailed article that q...
# 47  {'very_valuable': 'One article that subtly pus...
# 48  {'very_valuable': 'An estimate of the amount o...
# 49  {'very_valuable': 'Haiti plans to reinstate th...
# 50  {'very_valuable': 'Gives details about causes,...
# 51  {'very_valuable': 'Record number of Ukrainian ...
# 52  {'very_valuable': 'N/A', 'somewhat_valuable': ...
# 53  {'very_valuable': 'N/A', 'somewhat_valuable': ...
#
#                                                report  \
# 0   Announcement of engagement\nPrincess Eugenie o...
# 1   Sovereignty\nSee also: Disputed status of Gibr...
# 2   South Korea reactions\n\t\nThis section is in ...
# 3   On 3 September, at 3:31 AM UTC, the United Sta...
# 4   Portuguese discoveries (Portuguese: Descobrime...
# 5   On the night of 14–15 April 2014, 276 female s...
# 6   Mount Sinabung erupted after a centuries-long ...
# 7   The United Nations Framework Convention on Cli...
# 8   Keif al-Hal? triggered a debate on the country...
# 9   Several large quantities of illicitly produced...
# 10  Lion Air Flight 610 was a scheduled domestic p...
# 11  A series of deadly wildfires erupted across ce...
# 12  In the May 2018 elections, the incumbent Presi...
# 13  Stabilization of building and reconstruction\n...
# 14  Background\nBento Rodrigues Village right afte...
# 15  There are two subspecies of white rhino; the s...
# 16  In April 2018, Hedges travelled to the United ...
# 17  In October 2018, France froze Iranian financia...
# 18  The British commercial spaceport competition w...
# 19  There is concern about sea level rise caused b...
# 20  The 2017 Puebla earthquake struck at 13:14 CDT...
# 21  A protective housing/captive breeding program,...
# 22  The withdrawal of U.S. troops from Afghanistan...
# 23  Huaca Prieta is the site of a prehistoric sett...
# 24  The 2018 Papua New Guinea earthquake was an ea...
# 25  Landslide hazard analysis and mapping can prov...
# 26  The abundance of species extinctions considere...
# 27  On January 11, 2016, more than 1000 scholars a...
# 28  The Event Horizon Telescope (EHT) is a project...
# 29  On 10 April, the Syrian and Russian government...
# 30  Same-sex marriage has been legal since 1 Octob...
# 31  Trade between Iran and the United States reach...
# 32  Qatar is either a constitutional or an absolut...
# 33  Cost of the Games\nThe Oxford Olympics Study 2...
# 34  Just a week before the presidential election d...
# 35  North African ostrich in Morocco, Nigeria, Nig...
# 36  Warner Media, LLC (formerly Time Warner Inc.),...
# 37  Severe Tropical Cyclone Ron was one of the mos...
# 38  Saudi Vision 2030 is a plan to reduce Saudi Ar...
# 39  In the last three months of 2010, Ryanair made...
# 40  Efforts to sell the company\n\nBob Weinstein s...
# 41  Office of Hazardous Materials Safety (OHMS)\nO...
# 42  The German Climate Action Plan 2050 (German: K...
# 43  The Speaker of Parliament, Karu Jayasuriya has...
# 44  \nTechnology introduction\nOn April 9, 2004, t...
# 45  State-level government officials are also divi...
# 46                         Russia: #Ятоже (en: MeToo)
# 47  Dry, warm conditions in the spring set the sta...
# 48  The 2018 lower Puna eruption is an ongoing vol...
# 49  Disbandment\nFurther information: Operation Up...
# 50  2013\nOctober 19 – Philippines – 2013 Atimonan...
# 51  While the popularity of social networking cons...
# 52  Political observers have called Xi "the most p...
# 53  Illegal immigration from Africa to Europe is s...
#
#                                            report_url report_date  \
# 0   https://en.wikipedia.org/w/index.php?title=Wed...  2018-05-13
# 1   https://en.wikipedia.org/w/index.php?title=Eff...  2018-11-26
# 2   https://en.wikipedia.org/w/index.php?title=Uni...  2018-02-20
# 3   https://en.wikipedia.org/w/index.php?title=201...  2017-09-22
# 4   https://en.wikipedia.org/w/index.php?title=Por...  2018-05-16
# 5   https://en.wikipedia.org/w/index.php?title=Chi...  2018-02-11
# 6   https://en.wikipedia.org/w/index.php?title=Mou...  2018-02-19
# 7   https://en.wikipedia.org/w/index.php?title=Uni...  2018-10-06
# 8   https://en.wikipedia.org/w/index.php?title=Cin...  2018-04-16
# 9   https://en.wikipedia.org/w/index.php?title=Fen...  2019-03-30
# 10  https://en.wikipedia.org/w/index.php?title=Lio...  2018-10-29
# 11  https://en.wikipedia.org/w/index.php?title=Jun...  2017-06-18
# 12  https://en.wikipedia.org/w/index.php?title=Ven...  2019-01-21
# 13  https://en.wikipedia.org/w/index.php?title=Not...  2019-08-31
# 14  https://en.wikipedia.org/w/index.php?title=Bru...  2019-02-10
# 15  https://en.wikipedia.org/w/index.php?title=Whi...  2018-03-20
# 26               ru
# 27               ru
# 28               ru
# 29               ru
# 30               ru
# 31               ru
# 32               ru
# 33               ru
# 34               ru
# 35               ru
# 36               ru
# 37               ru
# 38               ru
# 39               ru
# 40               ru
# 41               ru
# 42               ru
# 43               ru
# 44               ru
# 45               ru
# 46               ru
# 47               ru
# 48               ru
# 49               ru
# 50               ru
# 51               ru
# 52               ru
# 53               ru

# %%
qrels = pd.DataFrame(datasets["ru"].qrels_iter())


# Check the count of each relevance score in qrels
relevance_counts = qrels["relevance"].value_counts()

# Determine the minimum count among relevance scores 0, 1, and 3 to ensure equal sampling
min_sample_count = 50

# Sample equally from each relevance score based on the minimum count
sample_0 = qrels[qrels["relevance"] == 0].sample(n=min_sample_count, random_state=42)
sample_1 = qrels[qrels["relevance"] == 1].sample(n=min_sample_count, random_state=42)
sample_3 = qrels[qrels["relevance"] == 3].sample(n=min_sample_count, random_state=42)

# Concatenate the samples into one DataFrame
sample = pd.concat([sample_0, sample_1, sample_3]).reset_index(drop=True)


doc_ids = sample["doc_id"].values
query_ids = sample["query_id"].values

docs = documents[documents["doc_id"].isin(doc_ids)]
queries = queries[queries["query_id"].isin(query_ids)]

print(docs["doc_id"].count())
print(queries["query_id"].count())

sample
# Out:
# 32
# 30
#     query_id                                doc_id  relevance iteration
# 0        192  00b8dacd-f427-4674-8d4c-9d55349f09c6          0         0
# 1        158  98b8d139-bb50-41b3-bcc5-9947e60fbea0          0         0
# 2        146  cebdec40-1b78-4b6d-aea4-2bec47d27db8          0         0
# 3        161  63e50279-4f81-4ea3-a6d1-62945eeb6f11          0         0
# 4        251  aafcdfe6-7775-486e-af55-70e5f007cc75          0         0
# ..       ...                                   ...        ...       ...
# 145      232  b8786279-cc7c-46aa-a4d4-443f9ce7bc81          3         0
# 146      103  2cba8cef-f155-4688-b842-dc6962a12ada          3         0
# 147      254  5e792c8d-d25b-44fd-90f6-8dcb3e3adbec          3         0
# 148      142  8f55f285-5f73-42f2-b54d-0558278d7d9e          3         0
# 149      252  7535a0bb-cf4b-4661-847f-667aac592ae0          3         0
#
# [150 rows x 4 columns]

# %%
pool = model.start_multi_process_pool(["cpu", "cpu", "cpu", "cpu"])
doc_embeddings = model.encode_multi_process(docs["text"].values, pool=pool, batch_size=10, show_progress_bar=True)
title_embeddings = model.encode_multi_process(docs["title"].values, pool=pool, batch_size=10, show_progress_bar=True)
query_embeddings = model.encode_multi_process(queries["description"].values, batch_size=10, show_progress_bar=True, pool=pool)

model.stop_multi_process_pool(pool)
# Out:
# Chunks:   0%|          | 0/32 [00:00<?, ?it/s]
# Chunks:   0%|          | 0/32 [00:00<?, ?it/s]
# Chunks:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
doc_embedding_pairs = {doc_id: embedding for doc_id, embedding in zip(docs["doc_id"], doc_embeddings)}
title_embedding_pairs = {doc_id: embedding for doc_id, embedding in zip(docs["doc_id"], title_embeddings)}
query_embedding_pairs = {query_id: embedding for query_id, embedding in zip(queries["query_id"], query_embeddings)}

# %%
# Assuming sample, query_embeddings, and doc_embeddings are already defined
results = []

for i, row in sample.iterrows():
    query_id = row["query_id"]
    doc_id = row["doc_id"]
    relevance = row["relevance"]

    # Check if the query_id exists in the mapping and if doc_id exists in the documents
    if query_id in query_embedding_pairs and doc_id in doc_embedding_pairs:
        query_embedding = query_embedding_pairs[query_id]
        doc_embedding = doc_embedding_pairs[doc_id]
        title_embedding = title_embedding_pairs[doc_id]
        
        similarity_doc = np.dot(query_embedding, doc_embedding)
        similarity_title = np.dot(query_embedding, title_embedding)
        results.append([query_id, doc_id, similarity_doc, similarity_title, relevance])

# Convert the results list to a DataFrame
df = pd.DataFrame(results, columns=["query_id", "doc_id", "similarity_doc", "similiarity_title", "relevance"])

# Print the resulting DataFrame
df
# Out:
#    query_id                                doc_id  similarity_doc  \
# 0       232  eec368bf-876e-4e86-83ff-56cc967b75b4        0.663229
# 1        13  b93df41a-7240-49d6-909c-e38814e07770        0.498686
# 2         6  8e7fa312-7615-48d0-80e7-e5e1d7458f6e        0.480728
# 3       134  ac7adb86-53b4-4371-b2ee-48b7d785a7f1        0.426618
# 4       255  a23fb9a5-dccf-4247-aa22-6f46b72be7ae        0.565778
# 5        13  61a806d1-0ebc-4c6c-8d5f-605bf02d293e        0.486842
# 6       248  9558b60f-2ec5-480a-8abb-7db03a2afc88        0.640485
# 7       172  069b4d10-2121-4755-a325-151dc140602b        0.366741
# 8       150  1df3b02e-5dc7-47ee-a2ef-8ba6d22e0d43        0.541192
# 9         6  ad60088c-f295-45d6-ad9b-4f498b7de791        0.618871
# 10        6  1be54d17-1299-48f8-a04c-e9672e0e8e2b        0.541770
# 11      150  4d5cdffa-a841-4487-b25e-d470599696a1        0.476862
# 12      128  72ecd29a-a70f-478e-a994-5a3866992ba0        0.459210
# 13      103  3247e976-8a1c-4abd-a28a-fce849663a09        0.507167
# 14      142  68ef49d9-c8d4-45e1-aeea-8ecf871894f2        0.615939
# 15      248  ed94a94c-a6e9-44a0-869f-cae95dd3c136        0.660393
# 16      233  8e6dc13e-3dd8-42b4-b4a8-91829d73f4cf        0.558162
# 17      248  3c5185b4-d819-4cfb-9252-2f9f5773845c        0.493493
# 18      108  ae676418-6145-42b6-8075-6b29ef71a410        0.617514
# 19      248  0001f521-56b2-415b-b739-70e63c17328b        0.564426
# 20      142  035e34cd-3685-4706-acb0-cd58a2d3c7af        0.617253
# 21      254  5e792c8d-d25b-44fd-90f6-8dcb3e3adbec        0.551251
# 22      142  8f55f285-5f73-42f2-b54d-0558278d7d9e        0.604684
#
#     similiarity_title  relevance
# 0            0.323594          0
# 1            0.439179          0
# 2            0.269829          0
# 3            0.496366          0
# 4            0.440132          0
# 5            0.508709          0
# 6            0.555054          0
# 7            0.429471          0
# 8            0.612064          1
# 9            0.598164          1
# 10           0.466908          1
# 11           0.455198          1
# 12           0.395396          1
# 13           0.430496          1
# 14           0.638153          3
# 15           0.513965          3
# 16           0.473663          3
# 17           0.473822          3
# 18           0.691368          3
# 19           0.493308          3
# 20           0.645923          3
# 21           0.546018          3
# 22           0.654105          3
